# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import random 
import seaborn as sns

pd.options.display.float_format = '{:.4f}'.format
import matplotlib.font_manager as fm

pd.set_option('display.max_columns', None)
pd.set_option('display.max_row', None)
pd.options.display.float_format = '{:.2f}'.format
# 설치된 폰트 출력
sns.set(font='Malgun Gothic')
plt.rcParams['font.size'] = 10
plt.rcParams['axes.unicode_minus'] = False
plt.rc('font', family='Malgun Gothic')

# %%
data1 = pd.read_csv('./df_data_137.csv')
data1.set_index('국가명',inplace=True)
data1
# Out:
#                             확진수        사망수          회복수           검사수  \
# 국가명
# Austria              5780229.00   21689.00   5730189.00  211273524.00
# Denmark              3173247.00    8145.00   3163849.00  129144754.00
# UAE                  1049409.00    2348.00   1032735.00  198638806.00
# Spain               13731478.00  118434.00  13557699.00  471036328.00
# Hong Kong            2877280.00   13358.00   2509483.00   76123870.00
# Greece               5708301.00   35630.00   5662212.00  102228365.00
# UK                  24274361.00  204171.00  24020088.00  522526476.00
# Bahrain               700452.00    1543.00    698400.00   10682444.00
# Czechia              4590019.00   42312.00   4538304.00   56893223.00
# Oman                  399449.00    4628.00    384669.00   25000000.00
# Portugal             5563907.00   26022.00   5532366.00   45915651.00
# Israel               4786189.00   12193.00   4768242.00   41373364.00
# Italy               25453789.00  186833.00  25014986.00  265478247.00
# Georgia              1814180.00   16926.00   1776548.00   16920079.00
# Latvia                975355.00    6218.00    968830.00    7858319.00
# Singapore            2217110.00    1722.00   2144490.00   24756666.00
# France              39524311.00  164233.00  39264546.00  271490188.00
# Lithuania            1296865.00    9545.00   1282528.00   10350770.00
# USA                104196861.00 1132935.00 101322779.00 1159832679.00
# Belgium              4691499.00   33557.00   4644681.00   36548544.00
# Australia           11295446.00   18615.00  11235771.00   78835048.00
# Ireland              1700253.00    8462.00   1685183.00   12984257.00
# Chile                5118981.00   63812.00   5051555.00   48127301.00
# Finland              1458619.00    8639.00   1447569.00   12017711.00
# Malaysia             5036593.00   36942.00   4989861.00   67665089.00
# Norway               1477856.00    5112.00   1471835.00   11002430.00
# Kuwait                662858.00    2570.00    660237.00    8455743.00
# Sweden               2693458.00   23246.00   2658039.00   19410527.00
# Russia              21958696.00  395108.00  21356008.00  273400000.00
# Uruguay              1032710.00    7609.00   1023939.00    6114822.00
# Canada               4550256.00   50380.00   4444013.00   66343123.00
# Panama               1029701.00    8596.00   1020206.00    7475016.00
# Jordan               1746997.00   14122.00   1731007.00   17201885.00
# Bulgaria             1295426.00   38179.00   1254491.00   10987749.00
# New Zealand          2182355.00    3781.00   2169320.00    7710637.00
# Netherlands          8582500.00   22989.00   8547771.00   25984435.00
# Germany             37779833.00  165711.00  37398100.00  122332384.00
# Belarus               994037.00    7118.00    985592.00   13646641.00
# Serbia               2471198.00   17701.00   2440527.00   12154486.00
# Romania              3325006.00   67576.00   3252104.00   26389988.00
# Qatar                 492534.00     686.00    491585.00    4065369.00
# Slovenia             1321852.00    7056.00   1311159.00    2824843.00
# Slovakia             1860893.00   20946.00   1839309.00    7390781.00
# Croatia              1267580.00   17877.00   1249168.00    5476183.00
# Cuba                 1112438.00    8530.00   1103799.00   14298479.00
# Taiwan               9569611.00   16356.00   9129766.00   30207485.00
# Saudi Arabia          827962.00    9574.00    815528.00   45048008.00
# Mongolia             1007871.00    2179.00   1005658.00    4030048.00
# Hungary              2192447.00   48677.00   2139857.00   11394556.00
# Peru                 4481621.00  218931.00   4258688.00   37754603.00
# Armenia               446008.00    8717.00    435162.00    3242901.00
# North Macedonia       346428.00    9638.00    336623.00    2216193.00
# Poland               6380225.00  118736.00   5335940.00   38118630.00
# Costa Rica           1186176.00    9158.00    860711.00    4659757.00
# Vietnam             11526508.00   43186.00  10612479.00   85826548.00
# Botswana              329227.00    2800.00    325934.00    2026898.00
# Moldova               598673.00   11953.00    504142.00    3216305.00
# Argentina           10037135.00  130421.00   9877032.00   35716069.00
# Ukraine              5370131.00  111020.00   5253302.00   32603805.00
# Japan               32588442.00   68399.00  21567425.00   92144639.00
# Azerbaijan            827944.00   10085.00    817654.00    7487550.00
# Lebanon              1228639.00   10790.00   1087587.00    4795578.00
# Colombia             6356309.00  142486.00   6179501.00   36951507.00
# Gabon                  48981.00     306.00     48674.00    1621909.00
# Albania               334167.00    3595.00    328951.00    1941032.00
# India               44682784.00  530740.00  44150289.00  915265788.00
# Iran                 7564350.00  144749.00   7337549.00   54420785.00
# Kazakhstan           1405917.00   13695.00   1383020.00   11575012.00
# Iraq                 2465545.00   25375.00   2439497.00   19544451.00
# Rwanda                133090.00    1468.00    131559.00    5959042.00
# South Africa         4055966.00  102595.00   3912506.00   26473049.00
# Tunisia              1150356.00   29308.00   1121048.00    4997373.00
# Indonesia            6730289.00  160817.00   6565208.00  114158919.00
# Namibia               170741.00    4088.00    166452.00    1062663.00
# El Salvador           201785.00    4230.00    179410.00    2610114.00
# Jamaica               153407.00    3480.00    102212.00    1183986.00
# Paraguay              806256.00   19820.00    786436.00    2657506.00
# Guatemala            1227853.00   20106.00   1204545.00    6757892.00
# Libya                 507162.00    6437.00    500721.00    2483446.00
# Morocco              1272240.00   16296.00   1255881.00   12930733.00
# Dominican Republic    660095.00    4384.00    644785.00    3740928.00
# S. Korea            30197066.00   33486.00  29740877.00   15804065.00
# Philippines          4073454.00   65802.00   3998048.00   34343332.00
# Sri Lanka             671989.00   16828.00    655158.00    6486117.00
# Brazil              36824580.00  697074.00  35919372.00   63776166.00
# Thailand             4726984.00   33865.00   4692636.00   17270775.00
# Bolivia              1187986.00   22346.00   1146143.00    2705422.00
# Mauritania             63665.00     997.00     62437.00    1009957.00
# Nepal                1001102.00   12020.00    989064.00    6003944.00
# Zambia                340763.00    4047.00    335104.00    3865993.00
# Lesotho                34790.00     723.00     25980.00     431221.00
# Cambodia              138693.00    3056.00    135624.00    3091420.00
# Myanmar               633820.00   19490.00    614299.00    9941945.00
# Ecuador              1051239.00   35942.00   1011682.00    3082403.00
# Laos                  217973.00     758.00    217215.00    1233207.00
# Zimbabwe              261606.00    5652.00    254951.00    2525756.00
# Honduras              470757.00   11104.00    459653.00    1619676.00
# Mexico               7368252.00  332198.00   6606633.00   19356195.00
# Pakistan             1576313.00   30640.00   1538689.00   30570862.00
# Venezuela             551587.00    5845.00    545003.00    3359014.00
# Togo                   39354.00     290.00     39061.00     806803.00
# Bangladesh           2037556.00   29442.00   1992694.00   15247014.00
# Ghana                 171112.00    1462.00    169636.00    2527319.00
# Kenya                 342810.00    5688.00    337040.00    3967062.00
# Guinea-Bissau           8947.00     176.00      8656.00     145231.00
# Senegal                88902.00    1971.00     86929.00    1146543.00
# Cameroon              123993.00    1965.00    118616.00    1751774.00
# Uganda                170400.00    3630.00    100431.00    3012408.00
# Gambia                 12586.00     372.00     12189.00     155686.00
# Congo                  25375.00     386.00     24006.00     347815.00
# Guinea                 38240.00     467.00     37757.00     660107.00
# Benin                  27989.00     163.00     27823.00     604310.00
# Angola                105184.00    1931.00    103216.00    1499795.00
# Uzbekistan            250567.00    1637.00    241486.00    1377915.00
# Mali                   32783.00     743.00     31957.00     789342.00
# South Sudan            18368.00     138.00     18115.00     410280.00
# Egypt                 515645.00   24613.00    442182.00    3693367.00
# Sierra Leone            7760.00     126.00      7634.00     259958.00
# Malawi                 88559.00    2686.00     85369.00     624784.00
# Afghanistan           208545.00    7882.00    186088.00    1188898.00
# Burundi                53492.00      38.00     53394.00     345742.00
# Papua New Guinea       46750.00     670.00     43982.00     249149.00
# Liberia                 8062.00     294.00      7766.00     139824.00
# Nigeria               266463.00    3155.00    259850.00    5708974.00
# Somalia                27318.00    1361.00     13182.00     400466.00
# Madagascar             67827.00    1419.00     66370.00     524209.00
# CAR                    15368.00     113.00     15200.00      81294.00
# Sudan                  63742.00    5001.00     58284.00     562941.00
# Haiti                  34076.00     860.00     33033.00     132422.00
# Burkina Faso           22025.00     396.00     21596.00     248995.00
# Chad                    7652.00     194.00      4874.00     191341.00
# Yemen                  11945.00    2159.00      9124.00     329592.00
# Niger                   9931.00     312.00      8890.00     254538.00
# DRC                    95514.00    1463.00     84264.00     846704.00
# Syria                  57453.00    3164.00     54289.00     146269.00
# Eritrea                10189.00     103.00     10086.00      23693.00
# Algeria               271378.00    6881.00    182749.00     230861.00
#
#                               인구     위도      경도          면적   확진수율  사망수율  \
# 국가명
# Austria               9066710.00  48.21   16.37    83879.00   2.74  0.38
# Denmark               5834950.00  55.68   12.56    42934.00   2.46  0.26
# UAE                  10081785.00  23.71   54.30    83600.00   0.53  0.22
# Spain                46719142.00  40.42   -3.72   505370.00   2.92  0.86
# Hong Kong             7604299.00  22.31  114.18     1114.00   3.78  0.46
# Greece               10316637.00  37.98   23.73   131957.00   5.58  0.62
# UK                   68497907.00  54.98   -2.80   243610.00   4.65  0.84
# Bahrain               1783983.00  26.23   50.58      765.00   6.56  0.22
# Czechia              10736784.00  50.08   14.42    78867.00   8.07  0.92
# Oman                  5323993.00  23.61   58.59   309500.00   1.60  1.16
# Portugal             10140570.00  38.71   -9.14    92226.00  12.12  0.47
# Israel                9326000.00  31.78   35.22    20325.00  11.57  0.25
# Italy                60262770.00  41.89   12.48   302072.00   9.59  0.73
# Georgia               3968738.00  41.72   44.79    69700.00  10.72  0.93
# Latvia                1848837.00  56.95   24.11    64589.00  12.41  0.64
# Singapore             5943546.00   1.30  103.80      719.00   8.96  0.08
# France               65584518.00  48.86    2.35   675417.00  14.56  0.42
# Lithuania             2661708.00  54.68   25.28    65300.00  12.53  0.74
# USA                 334805269.00  39.53 -102.06  9830000.00   8.98  1.09
# Belgium              11668278.00  50.84    4.33    30528.00  12.84  0.72
# Australia            26068792.00 -33.87  151.21  7690000.00  14.33  0.16
# Ireland               5020199.00  53.35   -6.26    70282.00  13.09  0.50
# Chile                19250195.00 -33.45  -70.67   756102.00  10.64  1.25
# Finland               5554960.00  60.18   24.93   338424.00  12.14  0.59
# Malaysia             33181072.00   3.15  101.70   330252.00   7.44  0.73
# Norway                5511370.00  59.91   10.75   386958.00  13.43  0.35
# Kuwait                4380326.00  29.38   47.98    17818.00   7.84  0.39
# Sweden               10218971.00  59.33   18.07   449964.00  13.88  0.86
# Russia              145805947.00  55.76   37.62 17090000.00   8.03  1.80
# Uruguay               3496016.00 -34.87  -56.17   176000.00  16.89  0.74
# Canada               38388419.00  43.74  -79.37  9980000.00   6.86  1.11
# Panama                4446964.00   9.00  -79.50    75420.00  13.78  0.83
# Jordan               10300869.00  31.95   35.93    89342.00  10.16  0.81
# Bulgaria              6844597.00  42.70   23.32   110000.00  11.79  2.95
# New Zealand           4898203.00 -36.85  174.78   270000.00  28.30  0.17
# Netherlands          17211447.00  52.37    4.88    41865.00  33.03  0.27
# Germany              83883596.00  52.52   13.38   357580.00  30.88  0.44
# Belarus               9432800.00  53.90   27.56   207600.00   7.28  0.72
# Serbia                8653016.00  44.82   20.47    88361.00  20.33  0.72
# Romania              19031335.00  44.40   26.08   238397.00  12.60  2.03
# Qatar                 2979915.00  25.30   51.53    11581.00  12.12  0.14
# Slovenia              2078034.00  46.05   14.52    20270.00  46.79  0.53
# Slovakia              5460193.00  48.14   17.11    49035.00  25.18  1.13
# Croatia               4059286.00  45.81   15.98    56594.00  23.15  1.41
# Cuba                 11305652.00  23.14  -82.36   110860.00   7.78  0.77
# Taiwan               23888595.00  24.15  120.67    36000.00  31.68  0.17
# Saudi Arabia         35844909.00  24.65   46.71  2150000.00   1.84  1.16
# Mongolia              3378078.00  47.92  106.91  1564000.00  25.01  0.22
# Hungary               9606259.00  47.50   19.04    93030.00  19.24  2.22
# Peru                 33684208.00 -12.06  -77.04  1280000.00  11.87  4.89
# Armenia               2971966.00  40.18   44.51    29743.00  13.75  1.95
# North Macedonia       2081304.00  41.65   21.65    25713.00  15.63  2.78
# Poland               37739785.00  52.23   21.01   312685.00  16.74  1.86
# Costa Rica            5182354.00   9.93  -84.08    51100.00  25.46  0.77
# Vietnam              98953541.00  10.82  106.63   330951.00  13.43  0.37
# Botswana              2441162.00 -24.66   25.91   582000.00  16.24  0.85
# Moldova               4013171.00  47.02   28.84    33851.00  18.61  2.00
# Argentina            46010234.00 -34.60  -58.38  2790000.00  28.10  1.30
# Ukraine              43192122.00  50.45   30.52   603500.00  16.47  2.07
# Japan               125584838.00  35.68  139.77   378000.00  35.37  0.21
# Azerbaijan           10300205.00  40.37   49.84    86600.00  11.06  1.22
# Lebanon               6684849.00  33.89   35.51    10452.00  25.62  0.88
# Colombia             51512762.00   4.61  -74.07  1140000.00  17.20  2.24
# Gabon                 2331533.00   0.39    9.45   267000.00   3.02  0.62
# Albania               2866374.00  41.33   19.82    28748.00  17.22  1.08
# India              1406631776.00  28.67   77.22  3287782.00   4.88  1.19
# Iran                 86022837.00  35.70   51.42  1640000.00  13.90  1.91
# Kazakhstan           19205043.00  43.25   76.90  2724900.00  12.15  0.97
# Iraq                 42164965.00  33.35   44.42   441839.00  12.62  1.03
# Rwanda               13600464.00  -1.95   30.06    26338.00   2.23  1.10
# South Africa         60756135.00 -26.20   28.04  1220000.00  15.32  2.53
# Tunisia              12046656.00  36.80   10.18   162155.00  23.02  2.55
# Indonesia           279134505.00  -6.21  106.85  1916820.00   5.90  2.39
# Namibia               2633874.00 -22.57   17.08   824269.00  16.07  2.39
# El Salvador           6550389.00  13.70  -89.19    21041.00   7.73  2.10
# Jamaica               2985094.00  17.97  -76.79    10991.00  12.96  2.27
# Paraguay              7305843.00 -25.30  -57.63   406752.00  30.34  2.46
# Guatemala            18584039.00  14.61  -90.53   108889.00  18.17  1.64
# Libya                 7040745.00  32.88   13.19  1759540.00  20.42  1.27
# Morocco              37772756.00  33.60   -7.62   710850.00   9.84  1.28
# Dominican Republic   11056370.00  18.48  -69.89    48670.00  17.65  0.66
# S. Korea             51329899.00  37.57  126.98   100210.00 191.07  0.11
# Philippines         112508994.00  14.60  120.98   300000.00  11.86  1.62
# Sri Lanka            21575842.00   6.92   79.83    65610.00  10.36  2.50
# Brazil              215353593.00 -23.55  -46.63  8510000.00  57.74  1.89
# Thailand             70078203.00  13.75  100.52   513000.00  27.37  0.72
# Bolivia              11992656.00 -17.79  -63.20  1098581.00  43.91  1.88
# Mauritania            4901981.00  18.09  -15.98  1030700.00   6.30  1.57
# Nepal                30225582.00  27.72   85.37   147516.00  16.67  1.20
# Zambia               19470234.00 -15.42   28.28   752614.00   8.81  1.19
# Lesotho               2175699.00 -29.31   27.48    30355.00   8.07  2.08
# Cambodia             17168639.00  11.57  104.92   181035.00   4.49  2.20
# Myanmar              55227143.00  16.80   96.16   677000.00   6.38  3.08
# Ecuador              18113361.00  -2.19  -79.89   283561.00  34.10  3.42
# Laos                  7481023.00  17.97  102.60   236000.00  17.68  0.35
# Zimbabwe             15331428.00 -17.83   31.05   390000.00  10.36  2.16
# Honduras             10221247.00  14.08  -87.22   112490.00  29.06  2.36
# Mexico              131562772.00  19.43  -99.13  1960000.00  38.07  4.51
# Pakistan            229488994.00  24.86   67.01   803940.00   5.16  1.94
# Venezuela            29266991.00  10.50  -66.93  9120505.00  16.42  1.06
# Togo                  8680837.00   6.13    1.22    56785.00   4.88  0.74
# Bangladesh          167885689.00  23.73   90.39   147570.00  13.36  1.44
# Ghana                32395450.00   5.60   -0.19   238533.00   6.77  0.85
# Kenya                56215221.00  -1.29   36.82   580000.00   8.64  1.66
# Guinea-Bissau         2063367.00  11.86  -15.60    36125.00   6.16  1.97
# Senegal              17653671.00  14.75  -17.40   196712.00   7.75  2.22
# Cameroon             27911548.00   3.86   11.52   475650.00   7.08  1.58
# Uganda               48432863.00   0.31   32.58   241038.00   5.66  2.13
# Gambia                2558482.00  13.44  -15.40    11295.00   8.08  2.96
# Congo                 5797805.00  -2.92   23.74   342000.00   7.30  1.52
# Guinea               13865691.00   9.54  -13.68   246000.00   5.79  1.22
# Benin                12784726.00   6.40    2.52   112622.00   4.63  0.58
# Angola               35027343.00  -8.84   13.23  1246700.00   7.01  1.84
# Uzbekistan           34382084.00  41.30   69.27   447400.00  18.18  0.65
# Mali                 21473764.00  12.65   -7.99  1240192.00   4.15  2.27
# South Sudan          11618511.00   4.85   31.60   644000.00   4.48  0.75
# Egypt               106156692.00  30.04   31.24   997739.00  13.96  4.77
# Sierra Leone          8306436.00   8.48  -13.23    71740.00   2.99  1.62
# Malawi               20180839.00 -15.79   35.01   118484.00  14.17  3.03
# Afghanistan          40754388.00  34.53   69.17   652000.00  17.54  3.78
# Burundi              12624840.00  -3.38   29.36    27834.00  15.47  0.07
# Papua New Guinea      9292169.00  -9.48  147.15   452860.00  18.76  1.43
# Liberia               5305117.00   6.31  -10.80   113370.00   5.77  3.65
# Nigeria             216746934.00   6.45    3.40   923768.00   4.67  1.18
# Somalia              16841795.00   2.04   45.34   637661.00   6.82  4.98
# Madagascar           29178077.00 -18.94   47.52   587041.00  12.94  2.09
# CAR                   5016678.00   6.57   20.49   623000.00  18.90  0.74
# Sudan                45992020.00  15.60   32.53  1861484.00  11.32  7.85
# Haiti                11680283.00  18.54  -72.34    27750.00  25.73  2.52
# Burkina Faso         22102838.00  12.37   -1.53   274200.00   8.85  1.80
# Chad                 17413580.00  12.11   15.05  1284000.00   4.00  2.54
# Yemen                31154867.00  15.35   44.20   527968.00   3.62 18.07
# Niger                26083660.00  13.51    2.11  1267000.00   3.90  3.14
# DRC                  95240792.00  -2.60   22.27  2345408.00  11.28  1.53
# Syria                19364809.00  36.20   37.15   185180.00  39.28  5.51
# Eritrea               3662244.00  15.33   38.92   117600.00  43.00  1.01
# Algeria              45350148.00  36.78    3.06  2381741.00 117.55  2.54
#
#                     회복수율    검사수율    인구밀도   감염율
# 국가명
# Austria            99.13 2330.21  108.09 63.75
# Denmark            99.70 2213.30  135.91 54.38
# UAE                98.41 1970.27  120.60 10.41
# Spain              98.73 1008.23   92.45 29.39
# Hong Kong          87.22 1001.06 6826.12 37.84
# Greece             99.19  990.91   78.18 55.33
# UK                 98.95  762.84  281.18 35.44
# Bahrain            99.71  598.80 2332.00 39.26
# Czechia            98.87  529.89  136.14 42.75
# Oman               96.30  469.57   17.20  7.50
# Portugal           99.43  452.79  109.95 54.87
# Israel             99.63  443.63  458.84 51.32
# Italy              98.28  440.53  199.50 42.24
# Georgia            97.93  426.33   56.94 45.71
# Latvia             99.33  425.04   28.62 52.76
# Singapore          96.72  416.53 8266.41 37.30
# France             99.34  413.95   97.10 60.26
# Lithuania          98.89  388.88   40.76 48.72
# USA                97.24  346.42   34.06 31.12
# Belgium            99.00  313.23  382.22 40.21
# Australia          99.47  302.41    3.39 43.33
# Ireland            99.11  258.64   71.43 33.87
# Chile              98.68  250.01   25.46 26.59
# Finland            99.24  216.34   16.41 26.26
# Malaysia           99.07  203.93  100.47 15.18
# Norway             99.59  199.63   14.24 26.81
# Kuwait             99.60  193.04  245.84 15.13
# Sweden             98.68  189.95   22.71 26.36
# Russia             97.26  187.51    8.53 15.06
# Uruguay            99.15  174.91   19.86 29.54
# Canada             97.67  172.82    3.85 11.85
# Panama             99.08  168.09   58.96 23.16
# Jordan             99.08  166.99  115.30 16.96
# Bulgaria           96.84  160.53   62.22 18.93
# New Zealand        99.40  157.42   18.14 44.55
# Netherlands        99.60  150.97  411.12 49.87
# Germany            98.99  145.84  234.59 45.04
# Belarus            99.15  144.67   45.44 10.54
# Serbia             98.76  140.47   97.93 28.56
# Romania            97.81  138.67   79.83 17.47
# Qatar              99.81  136.43  257.31 16.53
# Slovenia           99.19  135.94  102.52 63.61
# Slovakia           98.84  135.36  111.35 34.08
# Croatia            98.55  134.91   71.73 31.23
# Cuba               99.22  126.47  101.98  9.84
# Taiwan             95.40  126.45  663.57 40.06
# Saudi Arabia       98.50  125.67   16.67  2.31
# Mongolia           99.78  119.30    2.16 29.84
# Hungary            97.60  118.62  103.26 22.82
# Peru               95.03  112.08   26.32 13.30
# Armenia            97.57  109.12   99.92 15.01
# North Macedonia    97.17  106.48   80.94 16.64
# Poland             83.63  101.00  120.70 16.91
# Costa Rica         72.56   89.92  101.42 22.89
# Vietnam            92.07   86.73  299.00 11.65
# Botswana           99.00   83.03    4.19 13.49
# Moldova            84.21   80.14  118.55 14.92
# Argentina          98.40   77.63   16.49 21.82
# Ukraine            97.82   75.49   71.57 12.43
# Japan              66.18   73.37  332.24 25.95
# Azerbaijan         98.76   72.69  118.94  8.04
# Lebanon            88.52   71.74  639.58 18.38
# Colombia           97.22   71.73   45.19 12.34
# Gabon              99.37   69.56    8.73  2.10
# Albania            98.44   67.72   99.71 11.66
# India              98.81   65.07  427.84  3.18
# Iran               97.00   63.26   52.45  8.79
# Kazakhstan         98.37   60.27    7.05  7.32
# Iraq               98.94   46.35   95.43  5.85
# Rwanda             98.85   43.81  516.38  0.98
# South Africa       96.46   43.57   49.80  6.68
# Tunisia            97.45   41.48   74.29  9.55
# Indonesia          97.55   40.90  145.62  2.41
# Namibia            97.49   40.35    3.20  6.48
# El Salvador        88.91   39.85  311.32  3.08
# Jamaica            66.63   39.66  271.59  5.14
# Paraguay           97.54   36.38   17.96 11.04
# Guatemala          98.10   36.36  170.67  6.61
# Libya              98.73   35.27    4.00  7.20
# Morocco            98.71   34.23   53.14  3.37
# Dominican Republic 97.68   33.84  227.17  5.97
# S. Korea           98.49   30.79  512.22 58.83
# Philippines        98.15   30.52  375.03  3.62
# Sri Lanka          97.50   30.06  328.85  3.11
# Brazil             97.54   29.61   25.31 17.10
# Thailand           99.27   24.65  136.60  6.75
# Bolivia            96.48   22.56   10.92  9.91
# Mauritania         98.07   20.60    4.76  1.30
# Nepal              98.80   19.86  204.90  3.31
# Zambia             98.34   19.86   25.87  1.75
# Lesotho            74.68   19.82   71.68  1.60
# Cambodia           97.79   18.01   94.84  0.81
# Myanmar            96.92   18.00   81.58  1.15
# Ecuador            96.24   17.02   63.88  5.80
# Laos               99.65   16.48   31.70  2.91
# Zimbabwe           97.46   16.47   39.31  1.71
# Honduras           97.64   15.85   90.86  4.61
# Mexico             89.66   14.71   67.12  5.60
# Pakistan           97.61   13.32  285.46  0.69
# Venezuela          98.81   11.48    3.21  1.88
# Togo               99.26    9.29  152.87  0.45
# Bangladesh         97.80    9.08 1137.67  1.21
# Ghana              99.14    7.80  135.81  0.53
# Kenya              98.32    7.06   96.92  0.61
# Guinea-Bissau      96.75    7.04   57.12  0.43
# Senegal            97.78    6.49   89.74  0.50
# Cameroon           95.66    6.28   58.68  0.44
# Uganda             58.94    6.22  200.93  0.35
# Gambia             96.85    6.09  226.51  0.49
# Congo              94.60    6.00   16.95  0.44
# Guinea             98.74    4.76   56.36  0.28
# Benin              99.41    4.73  113.52  0.22
# Angola             98.13    4.28   28.10  0.30
# Uzbekistan         96.38    4.01   76.85  0.73
# Mali               97.48    3.68   17.31  0.15
# South Sudan        98.62    3.53   18.04  0.16
# Egypt              85.75    3.48  106.40  0.49
# Sierra Leone       98.38    3.13  115.79  0.09
# Malawi             96.40    3.10  170.33  0.44
# Afghanistan        89.23    2.92   62.51  0.51
# Burundi            99.82    2.74  453.58  0.42
# Papua New Guinea   94.08    2.68   20.52  0.50
# Liberia            96.33    2.64   46.79  0.15
# Nigeria            97.52    2.63  234.63  0.12
# Somalia            48.25    2.38   26.41  0.16
# Madagascar         97.85    1.80   49.70  0.23
# CAR                98.91    1.62    8.05  0.31
# Sudan              91.44    1.22   24.71  0.14
# Haiti              96.94    1.13  420.91  0.29
# Burkina Faso       98.05    1.13   80.61  0.10
# Chad               63.70    1.10   13.56  0.04
# Yemen              76.38    1.06   59.01  0.04
# Niger              89.52    0.98   20.59  0.04
# DRC                88.22    0.89   40.61  0.10
# Syria              94.49    0.76  104.57  0.30
# Eritrea            98.99    0.65   31.14  0.28
# Algeria            67.34    0.51   19.04  0.60

# %%
# 열기준 정렬 함수
def sort_data(df,str_x):
    str_x =str(str_x)
    #x = str(input(f'정렬할 기준 열 이름 입력 : {df.columns}'))
    print()
    df = df.sort_values(str_x)
    return df

# 표준 점수
def z_score(x):
    return (x-x.mean())/x.std()

# 정규화 함수
def nomaliz(x):
    return (x-x.min())/(x.max()-x.min())

# %%
# 시각화를 위한 요소간 격차를 줄이는 감쇠 매핑함수
def weakn(df,root_num):
    root_num = int(root_num)
    #root_num = int(input('.pipe(n 제곱근), 숫자(정수) n 입력 : '))
    print()
    return df.pipe(lambda a : a**(1/root_num)).pipe(nomaliz)

# 데이터 프레임에서 원하는 수만큼 
def random_nums(df,sample_idx):
    sample_idx = int(sample_idx)
    #sample_idx = int(input(f'랜덤 추출 수 입력( 0 ≤ x ≤ {len(df.index)} ) : '))
    print()
    nums = random.sample(range(0,len(df.index)), sample_idx)
    return nums

# %%
def groupABC(value):
    if value == 'A-1':
        return 'A'
    elif value == 'A-2':
        return 'A'
    elif value == 'A-3':
        return 'A'
    elif value == 'B':
        return 'B'
    else:
        return 'C'

# %%
def groupin(df,x):
    x =str(x)
    df['분할'] = df['분할'].apply(groupABC)
    df = df.groupby('분할')
    df = df.get_group(x)
    return df

# %%
def binning():
    df3 = data1[['사망수율','검사수율']]
    count, bin_dividers= np.histogram(df3['사망수율'], bins=5)
    bin_names = ['C','B','A-3','A-2','A-1']
    df3['분할']= pd.cut(x=df3['사망수율'],
                       bins=bin_dividers,
                       labels=bin_names,
                       include_lowest=True)


    df3.reset_index(inplace=True)
    df3.set_index(['국가명'],inplace=True)
    df3= sort_data(df3,'사망수율')

    return df3

# %%
def corr_heatmap():
    corr = pd.DataFrame(index= data1.columns, columns= data1.columns)
    corr.drop(['회복수','위도','경도','면적','회복수율'], axis=0, inplace=True)
    corr.drop(['회복수','위도','경도','면적','회복수율'], axis=1, inplace=True)

    for colx in corr.columns:
        for coly in corr.columns:
            a = np.corrcoef(data1[colx], data1[coly])
            corr.loc[colx][coly] = a[0,1]
    

    A = corr
    A = A.pipe(lambda c: c*100)
    A = A.astype(int)
    ax = sns.heatmap(A,cmap = 'seismic')

# %%
# df를 열이름 x의 오름차순으로 정렬후 10~120번째까지 자료들로 pair_plot 그리는 함수
# '검사수율','확진수율', '사망수율', '감염율','인구밀도' 열 사용
# 검사수율 = 검사수/인구 , 확진수율 = 확진수/검사수  , 사망수율 = 사망수/확진수, 감염율 = 확진수/인구 , 인구밀도 = 인구/ 면적
def pair_plt(str_x,num):
    df = data1.loc[:,['검사수율','확진수율', '사망수율', '감염율','인구밀도']]
    df = sort_data(df,str_x)
    df = weakn(df,num)
    
    g1= sns.pairplot(df, kind='reg',markers='o')

# %%
# 4개 열 요소를 이용한 조인트함수
def joint_gr(str_x,sample_idx,x):
    
    df = data1[['검사수율', '사망수율', '감염율','인구밀도']]
    df.columns = ['Rate_Tst', 'Rate_Dth', 'Rate_Inf', 'Pop_den'] # 한글 폰트 깨짐 해결이 안됨;;;ㅠ
    sort_data(df,str_x)
    nums = random_nums(df,sample_idx)
    df = df.iloc[nums]
    df = weakn(df,x)

    sns.set_style('whitegrid')
    j1 = sns.jointplot(x='Rate_Tst', y='Rate_Dth',kind='reg', data=df)
    j2 = sns.jointplot(x='Pop_den', y='Rate_Inf',kind='reg', data=df)

    plt.show()

# %%
# 사망수율과 검사수율에 대한 이중 차트를 출력하는 그룹지정(x)함수
def DCaseChart_group(col1,col2,ABC):
    df = data1[[col1,col2]]
    df = binning()
    df = groupin(df,ABC)
    dict_col = {'사망수율':'Death_Case', '검사수율':'Case_Population'}
    df.columns = [dict_col[col1],dict_col[col2],'분할']
    df = sort_data(df,dict_col[col1])

    plt.style.use('ggplot')
    df.columns = ['line', dict_col[col2],'분할']
    plt.rcParams['axes.unicode_minus']=True
    ax1 = df[dict_col[col2]].plot(kind='bar',figsize = (20,10), stacked=False)
    ax2 = ax1.twinx()
    ax2.plot(df.index,df.line, ls ='--',marker='o',color = 'green')
    
    plt.show()

# %%
# x축을 col1 열을 기준으로 오름차순으로 정렬돤 col2(bar)와 col3(line)의 이중차트를 생성하는 함수
def DCaseChart(col1, col2, col3, x):
    df = data1[[col1, col2, col3]]
    df.columns = [col1, col2, 'line']
    df = sort_data(df, col1)
    df = weakn(df,5)
    plt.style.use('ggplot')
    plt.rcParams['axes.unicode_minus']=True
    ax1 = df[col2].plot(kind='bar',figsize = (20,10), stacked=False)
    ax2 = ax1.twinx()
    ax2.plot(df.index, df.line, ls ='--',marker='o',color = 'green')
    
    plt.show()

# %%
# 상관관계 히트맵 빨강/파랑 : 양/음의 상관관계

corr_heatmap()

# %%
# 히트맵의 결과를 통해 pairplot으로 확진수율 ~ 감염율까지의 상관관계를 좀더 자세히 봄
pair_plt('검사수율',3)
# 모든 요소가 세제곱근 배 적용된 그래프 -> 검사수율, 3 차례로 입력

# %%
joint_gr('Rate_Tst',80,5)
# 'Rate_Tst'열을 기준으로 정렬 -> 80개 의 샘플 선택 -> 간격 축소 5

# %%
DCaseChart('사망수율','검사수율','사망수율',5)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44397 (\N{HANGUL SYLLABLE GUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 47749 (\N{HANGUL SYLLABLE MYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
DCaseChart('검사수율','사망수율','검사수율',5)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44397 (\N{HANGUL SYLLABLE GUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 47749 (\N{HANGUL SYLLABLE MYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 검사수율 증가(line)에 따른 사망율(bar) 그래프
DCaseChart_group('검사수율','사망수율','A')
DCaseChart_group('검사수율','사망수율','B')
DCaseChart_group('검사수율','사망수율','C')
# Out:
# C:\Users\82104\AppData\Local\Temp\ipykernel_8404\4042942046.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['분할']= pd.cut(x=df3['사망수율'],
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44397 (\N{HANGUL SYLLABLE GUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 47749 (\N{HANGUL SYLLABLE MYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\82104\AppData\Local\Temp\ipykernel_8404\4042942046.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['분할']= pd.cut(x=df3['사망수율'],
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44397 (\N{HANGUL SYLLABLE GUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 47749 (\N{HANGUL SYLLABLE MYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\82104\AppData\Local\Temp\ipykernel_8404\4042942046.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['분할']= pd.cut(x=df3['사망수율'],
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44397 (\N{HANGUL SYLLABLE GUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 47749 (\N{HANGUL SYLLABLE MYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 사망율 증가에 따른 검사수율 그래프

DCaseChart_group('사망수율','검사수율','A')
DCaseChart_group('사망수율','검사수율','B')
DCaseChart_group('사망수율','검사수율','C')
# 자료상
# Out:
# C:\Users\82104\AppData\Local\Temp\ipykernel_8404\4042942046.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['분할']= pd.cut(x=df3['사망수율'],
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44397 (\N{HANGUL SYLLABLE GUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 47749 (\N{HANGUL SYLLABLE MYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\82104\AppData\Local\Temp\ipykernel_8404\4042942046.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['분할']= pd.cut(x=df3['사망수율'],
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44397 (\N{HANGUL SYLLABLE GUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 47749 (\N{HANGUL SYLLABLE MYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\82104\AppData\Local\Temp\ipykernel_8404\4042942046.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['분할']= pd.cut(x=df3['사망수율'],
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44397 (\N{HANGUL SYLLABLE GUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 47749 (\N{HANGUL SYLLABLE MYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
